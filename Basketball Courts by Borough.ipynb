# %%
! pip install plotly
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
b_ball=pd.read_json('DPR_Basketball_001.json')

# %%
b_ball['Borough']='Default Value'
#rowIndex=b_ball.index[0]
#a=b_ball.loc[rowIndex,'Borough']='Bronx'

# %%
b_ball
# Out:
#     Accessible                                           Location  \
# 0            N                       E 174 St. & Bronx River Ave.
# 1            N                          Kelly St. & Ave. St. John
# 2            N                            Tinton Ave. & E 156 St.
# 3            N                            Barnes Ave. & E 215 St.
# 4            N                               Bouck & Throop Aves.
# 5            N      Gun Hill Rd., Eastchester Rd. and O'Neill Pl.
# 6            N  W 183 St., Aqueduct Ave., W Tremont Ave. and U...
# 7            N                            E 164 St. & Teller Ave.
# 8            N                     Bailey Ave. & W 234-W 238 Sts.
# 9            N              E 166 St., Union Ave. and Tinton Ave.
# 10           N                           Crotona Ave. & E 181 St.
# 11           N                        Bronxdale Ave. & Bronx Pk E
# 12           N        Boscobel Pl., University Ave. and W 171 St.
# ...

# %%
for index,row in b_ball.iterrows():
    if 'X'in row['Prop_ID']:
        b_ball.at[index,'Borough']='Bronx'
    elif 'B' in row['Prop_ID']:
        b_ball.at[index,'Borough'] ='Brooklyn'
    elif 'M' in row['Prop_ID']:
        b_ball.at[index,'Borough']='Manhattan'
    elif 'Q' in row['Prop_ID']:
        b_ball.at[index,'Borough']='Queens'
    else:
        b_ball.at[index,'Borough']='Staten Island'
b_ball
# Out:
#     Accessible                                           Location  \
# 0            N                       E 174 St. & Bronx River Ave.
# 1            N                          Kelly St. & Ave. St. John
# 2            N                            Tinton Ave. & E 156 St.
# 3            N                            Barnes Ave. & E 215 St.
# 4            N                               Bouck & Throop Aves.
# 5            N      Gun Hill Rd., Eastchester Rd. and O'Neill Pl.
# 6            N  W 183 St., Aqueduct Ave., W Tremont Ave. and U...
# 7            N                            E 164 St. & Teller Ave.
# 8            N                     Bailey Ave. & W 234-W 238 Sts.
# 9            N              E 166 St., Union Ave. and Tinton Ave.
# 10           N                           Crotona Ave. & E 181 St.
# 11           N                        Bronxdale Ave. & Bronx Pk E
# 12           N        Boscobel Pl., University Ave. and W 171 St.
# ...

# %%
borough_breakdown=b_ball[['Borough']]

# %%
bb_down=borough_breakdown['Borough'].value_counts().to_frame().reset_index()

# %%
bb_down
# Out:
#            index  Borough
# 0       Brooklyn      180
# 1         Queens      119
# 2      Manhattan      114
# 3          Bronx      110
# 4  Staten Island       35

# %%
! pip install cufflinks --upgrade
# Out:
# ...
#     100% |████████████████████████████████| 81kB 568kB/s ta 0:00:011
# Requirement not upgraded as not directly required: numpy>=1.9.2 in /Users/Valli/anaconda3/lib/python3.7/site-packages (from cufflinks) (1.15.1)
# Requirement not upgraded as not directly required: pandas>=0.19.2 in /Users/Valli/anaconda3/lib/python3.7/site-packages (from cufflinks) (0.23.4)
# ...
#     100% |████████████████████████████████| 41.5MB 122kB/s eta 0:00:01
# Requirement not upgraded as not directly required: six>=1.9.0 in /Users/Valli/anaconda3/lib/python3.7/site-packages (from cufflinks) (1.11.0)
# Requirement not upgraded as not directly required: colorlover>=0.2.1 in /Users/Valli/anaconda3/lib/python3.7/site-packages (from cufflinks) (0.3.0)
# Requirement not upgraded as not directly required: setuptools>=34.4.1 in /Users/Valli/anaconda3/lib/python3.7/site-packages (from cufflinks) (40.2.0)
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

#import cufflinks

from plotly.offline import iplot

#cufflinks.go_offline()
#cufflinks.set_config_file(world_readable=True, theme='pearl')

#py.tools.set_credentials_file(username='vlakshmanan', api_key='xgJ9TxqYUUF06q1juxqi')

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Brooklyn', 'Queens', 'Manhattan', 'Bronx','Staten Island'
sizes = [180, 119, 114, 110,35]
explode = (0.1, 0, 0, 0,0)  

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
